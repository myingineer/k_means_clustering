# %% [markdown]
# <a href="https://colab.research.google.com/github/myingineer/k_means_clustering/blob/main/kMeanClustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
# Generate Random Variables
X = np.random.rand(50, 2)
Y = 2 + np.random.rand(50, 2)

# Gather random variables in a dataframe
Z = np.concatenate((X, Y))
df = pd.DataFrame(Z, columns=['xpt', 'ypt'])

df.head()
# Out:
#         xpt       ypt
# 0  0.283215  0.139848
# 1  0.345999  0.885952
# 2  0.988298  0.416155
# 3  0.177095  0.846633
# 4  0.911026  0.098194

# %%
# Clustering
kmeans = KMeans(n_clusters=2, random_state=0).fit(Z)

# Extract the centriods of clusters into a dataframe
centers = kmeans.cluster_centers_
centroids = pd.DataFrame(centers, columns=['xpt', 'ypt'])

print(centroids)

# Extract the cluster labels
lab = kmeans.labels_

# Add cluster information to the dataframe
df['lab'] = lab

df.head()
# Out:
#         xpt       ypt
# 0  2.513814  2.524270
# 1  0.487743  0.498429
#         xpt       ypt  lab
# 0  0.283215  0.139848    1
# 1  0.345999  0.885952    1
# 2  0.988298  0.416155    1
# 3  0.177095  0.846633    1
# 4  0.911026  0.098194    1

# %%
# Create a figure and axes
fig, ax = plt.subplots(figsize=(6, 4))

# Add the data points
ax.scatter(x=df['xpt'], y=df['ypt'], c=df['lab'])

# Add the cluster centriods
ax.scatter(centroids['xpt'], centroids['ypt'])

# Set the axis scale on both axes equally
ax.axis('equal')

plt.show()
